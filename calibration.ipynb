# %% [markdown]
# # Dobot Tool Calibration Check
#
# Pose format: `[x, y, z, rx, ry, rz]`.

# %%
import config
from Dobot import get_robot_error, initialize_robot

dobot, feed_thread, saved_start_pose = initialize_robot(
    config.DOBOT_IP,
    config.SPEED_RATIO,
)

if get_robot_error(dobot):
    raise RuntimeError("Dobot has active errors. Stop before calibration.")

before_pose = dobot.GetCurrentPose()
print("Before pose:", before_pose)
# Out:
# Checking robot error information before enable...
# GetErrorID: Connection refused, IP:Port has been occupied
# Failed to query robot error ID. Stop for safety.
# Robot has active errors. Stop before EnableRobot.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 4
#       1 import config
#       2 from Dobot import get_robot_error, initialize_robot
# ----> 4 dobot, feed_thread, saved_start_pose = initialize_robot(
#       5     config.DOBOT_IP,
#       6     config.SPEED_RATIO,
#       7 )
#       9 if get_robot_error(dobot):
#      10     raise RuntimeError("Dobot has active errors. Stop before calibration.")
#
# File c:\Users\Administrator\Desktop\robot-control-code\Dobot\dobot_control.py:67, in initialize_robot(ip, speed_ratio, dobot, feed_thread)
#      64     dobot = connect_robot(ip)
#      66 if not prepare_robot(dobot, speed_ratio):
# ---> 67     raise RuntimeError("Dobot prepare failed")
#      69 if has_robot_error(dobot):
#      70     raise RuntimeError("Dobot has active errors")
#
# RuntimeError: Dobot prepare failed

# %%
# Set tool coordinates, then move with MovL.
target_pose = before_pose.copy()

# To test a specific target instead, replace the line above with:
# target_pose = [100, 100, 0, 0, 0, 0]

set_tool_result = dobot.SetTool(config.TOOL_INDEX, config.TOOL_FRAME)
dobot.MoveLinearPoint(target_pose, config.SPEED_RATIO)

after_pose = dobot.GetCurrentPose()
print("SetTool result:", set_tool_result)
print("Target pose:", target_pose)
print("After pose:", after_pose)
# Out:
# SetTool(1,{0,0,0,0,0,0}): -2,{},SetTool(1,{0,0,0,0,0,0});
# MovL: -2,{},MovL(pose={-551.352000,-33.913000,252.450000,179.862400,2.077400,118.625700},v=75);
# [-2, -551, 352000, -33, 913000, 252, 450000, 179, 862400, 2, 77400, 118, 625700, 75]
# 指令下发失败，跳过等待: -2,{},MovL(pose={-551.352000,-33.913000,252.450000,179.862400,2.077400,118.625700},v=75);
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 8
#       4 # To test a specific target instead, replace the line above with:
#       5 # target_pose = [100, 100, 0, 0, 0, 0]
#       7 set_tool_result = dobot.SetTool(config.TOOL_INDEX, config.TOOL_FRAME)
# ----> 8 dobot.MoveLinearPoint(target_pose, config.SPEED_RATIO)
#      10 after_pose = dobot.GetCurrentPose()
#      11 print("SetTool result:", set_tool_result)
#
# File c:\Users\Administrator\Desktop\robot-control-code\Dobot\dobot.py:80, in Dobot.MoveLinearPoint(self, point, speed_ratio)
#      78 print("MovL:", move_result)
#      79 if not self.WaitCommandDone(move_result):
# ---> 80     raise RuntimeError("MovL failed or timed out")
#      81 return True
#
# RuntimeError: MovL failed or timed out

# %%
delta_pose = [after - before for before, after in zip(before_pose, after_pose)]

print("Before pose:", before_pose)
print("After pose:", after_pose)
print("Delta pose:", delta_pose)

report = {
    "tool_index": config.TOOL_INDEX,
    "tool_frame": config.TOOL_FRAME,
    "target_pose": target_pose,
    "before_pose": before_pose,
    "after_pose": after_pose,
    "delta_pose": delta_pose,
}

report
